# %%
import numpy as np
import cv2
import time
from PIL import Image
np.set_printoptions(threshold=np.inf)

# %%
orig_img_path = '/home/xilinx/jupyter_notebooks/common/data/duck/'+str(2) +'.jpg'
# !fswebcam  --no-banner --save {orig_img_path} -d /dev/video0 2> /dev/null
# !fswebcam  --no-banner --save {orig_img_path} -d /dev/video2 2
img = Image.open(orig_img_path)
img
# Out:
# --- Opening /dev/video2...
# Trying source module v4l2...
# /dev/video2 opened.
# No input was specified, using the first.
# Adjusting resolution from 384x288 to 640x480.
# --- Capturing frame...
# Captured frame in 0.00 seconds.
# --- Processing captured image...
# Disabling banner.
# Writing JPEG image to '/home/xilinx/jupyter_notebooks/common/data/duck/2.jpg'.
# Writing JPEG image to '2'.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F902A2BA8>

# %%
i = 7
orig_img_path = '/home/xilinx/jupyter_notebooks/common/data/jienigui/'+str(i) +'.jpg'
# !fswebcam  --no-banner --save {orig_img_path} -d /dev/video0 2> /dev/null
# !fswebcam  --no-banner --save {orig_img_path} -d /dev/video2 2
img = Image.open(orig_img_path)
img
# Out:
# --- Opening /dev/video0...
# Trying source module v4l2...
# /dev/video0 opened.
# No input was specified, using the first.
# Adjusting resolution from 384x288 to 640x480.
# --- Capturing frame...
# Captured frame in 0.00 seconds.
# --- Processing captured image...
# Disabling banner.
# Writing JPEG image to '/home/xilinx/jupyter_notebooks/common/data/jienigui/7.jpg'.
# Writing JPEG image to '2'.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F55ED7C50>

# %%
orig_img_path = '/home/xilinx/jupyter_notebooks/common/data/webcam'+str(1) +'.jpg'
# !fswebcam  --no-banner --save {orig_img_path} -d /dev/video0 2> /dev/null
# !fswebcam  --no-banner --save {orig_img_path} -d /dev/video0 2

img = Image.open(orig_img_path)
img
# Out:
# --- Opening /dev/video0...
# Trying source module v4l2...
# /dev/video0 opened.
# No input was specified, using the first.
# Adjusting resolution from 384x288 to 640x480.
# --- Capturing frame...
# Captured frame in 0.00 seconds.
# --- Processing captured image...
# Disabling banner.
# Writing JPEG image to '/home/xilinx/jupyter_notebooks/common/data/webcam1.jpg'.
# Writing JPEG image to '2'.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F72782EB8>
