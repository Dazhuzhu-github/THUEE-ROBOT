# %%
    #return list1

    # cv.imshow("final",img)
    # cv.waitKey(0)
    # cv.destroyAllWindows()
    # return 0


# def houfline(img):
#     print("Start Houfline!!!")
#     img = img[:,0:370]
#     #cv.imshow("img",img)
#     hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
#     l_blue = np.array([[100,43,46]])
#     h_blue = np.array([[124,255,255]])
#     l_green = np.array([[40,43,46]])
#     h_green = np.array([[70,255,255]])
#     mask = cv.inRange(hsv, l_blue, h_blue)
#     mask_g = cv.inRange(hsv, l_green, h_green)
    #res = cv.bitwise_and(img, img, mask = mask)
    # cv.imshow("img", img)
    #cv.imshow("mask", mask_g)
    # cv.waitKey(0)
    # cv.destroyAllWindows()
    # #cv.imshow("res", res)
#     list1 = []
#     edges = cv.Canny(mask_g,50,150,apertureSize = 3)
#     #cv.imshow("mask2", edges)
#     #lines = cv.HoughLinesP(mask_g,1,np.pi/180,100,minLineLength=100,maxLineGap=1)
#     lines = cv.HoughLinesP(edges,1,np.pi/180,70,minLineLength=10,maxLineGap=200)
#     if lines is None:
#         return 0,0,0
#     for line in lines:
#         x1,y1,x2,y2 = line[0]
#         m = (y1-y2)/(x1-x2)
#         p = [0,240]
#         a = y1-y2
#         b = x2-x1
#         c = x1*y2 - y1*x2
        #m = a/b
        #dis
        #print(a,b)
#         dis = abs(a*p[0]+b*p[1]+c)/math.sqrt(a*a+b*b)
#         flag = 0
#         if (len(list1) == 0) :
#             if(math.isinf(m)):
#                 break
#             list1.append([m,dis])
#             #list1.sort()
#             #print(list1)
#         else:
#             for i in range(0,len(list1)):
#                 if ( abs(math.atan(m)-math.atan(list1[i][0])) < 0.5 and abs(dis-list1[i][1])<500):
#                     # list1[i][0] = (m+list1[i][0])/2
#                     # list1[i][1] = (list1[i][1]+dis)/2
#                     flag = 1
#                     break
#                 elif(math.isinf(m)):
#                     flag = 1
#                     break
                    
#             if (flag == 0):               
#                 list1.append([m,dis])           
    #    cv.line(img,(x1,y1),(x2,y2),(0,255,0),2)
    #cv.imwrite('houghlines3.jpg',img)
    #print(list1)
    #cv.imshow("img",img)
    #cv.waitKey(0)
    #cv.destroyAllWindows()
    #shape (640,480 3)
